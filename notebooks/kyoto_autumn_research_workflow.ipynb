# %% [markdown]
# # 京都红叶季 × 气温研究：业务流程 Notebook
#
# 这个 notebook 是给人读的流程版：从“要解决什么旅行决策问题”开始，按 **数据获取 → 数据清洗 → 计算分析 → 图表辅助 → 总结结论** 展开。底层可复现脚本仍是 `scripts/fetch_and_analyze.py`。

# %% [markdown]
# ## 0. 业务问题与流程总览
#
# **业务问题：** 如果今年京都秋季偏暖或偏冷，红叶行程应该提前、保持、还是后移？
#
# **流程：**
#
# 1. 数据获取：使用气象厅官方物候与京都站日别气温。
# 2. 数据清洗：统一年份、缺测处理、构造红叶延迟天数与气温指标。
# 3. 计算分析：比较气温指标与红叶延迟之间的相关性和线性斜率。
# 4. 图表辅助：用年度走势、散点回归、相关性条形图解释结果。
# 5. 总结结论：把统计结果翻译成旅行选期规则。

# %%
from pathlib import Path
import csv
import math

ROOT = Path.cwd()
if not (ROOT / "data").exists() and (ROOT.parent / "data").exists():
    ROOT = ROOT.parent

SUMMARY = ROOT / "data" / "processed" / "kyoto_koyo_temperature_2010_2025_summary.csv"
DAILY = ROOT / "data" / "raw" / "kyoto_daily_temperature_oct_dec_2010_2025.csv"
CORRELATIONS = ROOT / "data" / "processed" / "correlation_results.csv"

def read_csv(path):
    with path.open(newline="", encoding="utf-8") as f:
        return list(csv.DictReader(f))

summary = read_csv(SUMMARY)
daily = read_csv(DAILY)
correlations = read_csv(CORRELATIONS)

print(f"repo root: {ROOT.name}")
print(f"summary rows: {len(summary)} years ({summary[0]['year']}-{summary[-1]['year']})")
print(f"daily rows: {len(daily)} records")
print(f"correlation metrics: {len(correlations)}")
# Out:
# repo root: kyoto_autumn_research
# summary rows: 16 years (2010-2025)
# daily rows: 1472 records
# correlation metrics: 12

# %% [markdown]
# ## 1. 数据获取
#
# 红叶时间采用气象厅生物季节观测的京都 `かえでの紅葉日`。气温采用气象厅过去天气数据的京都站日别值。
#
# Notebook 默认读取仓库里已经生成好的 CSV，避免每次打开都访问气象厅网站；如果要刷新数据，把下面的 `RUN_LIVE_FETCH` 改成 `True`，或直接在仓库根目录运行 `python3 scripts/fetch_and_analyze.py`。

# %%
PHENOLOGY_URL = "https://www.data.jma.go.jp/sakura/data/ruinenchi/015.csv"
WEATHER_URL_TEMPLATE = "https://www.data.jma.go.jp/stats/etrn/view/daily_s1.php?prec_no=61&block_no=47759&year=YYYY&month=MM&day=&view=p1"
RUN_LIVE_FETCH = False

print("红叶日数据源:", PHENOLOGY_URL)
print("气温数据源模板:", WEATHER_URL_TEMPLATE)
print("默认不实时抓取，直接读取仓库中的已生成 CSV；需要刷新时运行: python3 scripts/fetch_and_analyze.py")

if RUN_LIVE_FETCH:
    import importlib.util
    spec = importlib.util.spec_from_file_location("fetch_and_analyze", ROOT / "scripts" / "fetch_and_analyze.py")
    analysis = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(analysis)
    analysis.main()
# Out:
# 红叶日数据源: https://www.data.jma.go.jp/sakura/data/ruinenchi/015.csv
# 气温数据源模板: https://www.data.jma.go.jp/stats/etrn/view/daily_s1.php?prec_no=61&block_no=47759&year=YYYY&month=MM&day=&view=p1
# 默认不实时抓取，直接读取仓库中的已生成 CSV；需要刷新时运行: python3 scripts/fetch_and_analyze.py

# %% [markdown]
# ## 2. 数据清洗
#
# 清洗后的核心字段：
#
# - `red_md`：官方红叶日（月/日）。
# - `delay_vs_dec5_days`：相对平年 12/5 的偏移；正数表示偏晚，负数表示偏早。
# - `oct_mean_c` / `nov_mean_c` / `oct_nov_mean_c`：月均或阶段均温。
# - `nov_dec10_days_le_10c`：11/1—12/10 日均温 ≤10°C 的冷天数量。

# %%
def print_table(rows, headers):
    widths = [len(str(h)) for h in headers]
    for row in rows:
        for i, value in enumerate(row):
            widths[i] = max(widths[i], len(str(value)))
    print(" | ".join(str(headers[i]).ljust(widths[i]) for i in range(len(headers))))
    print("-+-".join("-" * w for w in widths))
    for row in rows:
        print(" | ".join(str(row[i]).ljust(widths[i]) for i in range(len(headers))))

core_rows = []
for r in summary:
    core_rows.append([r["year"], r["red_md"] or "缺测", "" if not r["delay_vs_dec5_days"] else f"{int(r['delay_vs_dec5_days']):+d}", f"{float(r['oct_mean_c']):.2f}", f"{float(r['nov_mean_c']):.2f}", f"{float(r['oct_nov_mean_c']):.2f}", r["nov_dec10_days_le_10c"]])

print_table(core_rows, ["year", "official red", "delay d", "Oct °C", "Nov °C", "Oct-Nov °C", "≤10°C days"])
# Out:
# year | official red | delay d | Oct °C | Nov °C | Oct-Nov °C | ≤10°C days
# -----+--------------+---------+--------+--------+------------+-----------
# 2010 | 12/13        | +8      | 19.11  | 11.75  | 15.49      | 13
# 2011 | 12/14        | +9      | 18.39  | 13.79  | 16.13      | 11
# 2012 | 12/07        | +2      | 18.22  | 11.14  | 14.74      | 20
# 2013 | 12/05        | +0      | 20.05  | 11.51  | 15.85      | 22
# 2014 | 12/09        | +4      | 18.75  | 13.15  | 16.00      | 13
# 2015 | 12/14        | +9      | 18.11  | 14.45  | 16.31      | 11
# 2016 | 12/06        | +1      | 19.70  | 12.49  | 16.15      | 12
# 2017 | 12/01        | -4      | 18.04  | 11.20  | 14.68      | 21
# 2018 | 12/12        | +7      | 18.72  | 13.49  | 16.15      | 5
# 2019 | 12/10        | +5      | 19.97  | 12.92  | 16.50      | 14
# 2020 | 12/07        | +2      | 17.91  | 13.63  | 15.80      | 12
# 2021 | 缺测           |         | 19.60  | 12.90  | 16.30      | 10
# 2022 | 12/12        | +7      | 18.13  | 14.13  | 16.16      | 10
# 2023 | 12/13        | +8      | 18.23  | 13.34  | 15.83      | 13
# 2024 | 12/20        | +15     | 21.60  | 14.20  | 17.96      | 11
# 2025 | 12/10        | +5      | 20.57  | 12.47  | 16.59      | 10

# %% [markdown]
# ### 2.1 缺测与覆盖检查
#
# 2021 年官方红叶值在气象厅累年 CSV 中为 `0`，不应强行当作日期；这里按缺测处理，但保留当年的气温记录。

# %%
coverage = {}
for r in daily:
    coverage[(r["year"], r["month"])] = coverage.get((r["year"], r["month"]), 0) + 1

coverage_bad = [k for k, v in sorted(coverage.items()) if v not in (30, 31)]
sample_2025 = next(r for r in daily if r["date"] == "2025-11-01")

print("缺测策略: 2021 年官方かえで紅葉值为 0，按缺测处理；气温数据仍保留。")
print(f"日别覆盖: {len(coverage)} 个 year-month 组合；异常组合: {coverage_bad or '无'}")
print(f"样例 2025-11-01: 平均 {sample_2025['t_mean_c']}°C, 最高 {sample_2025['t_max_c']}°C, 最低 {sample_2025['t_min_c']}°C")
# Out:
# 缺测策略: 2021 年官方かえで紅葉值为 0，按缺测处理；气温数据仍保留。
# 日别覆盖: 48 个 year-month 组合；异常组合: 无
# 样例 2025-11-01: 平均 15.700000°C, 最高 21.300000°C, 最低 12.200000°C

# %% [markdown]
# ## 3. 计算分析
#
# 目标变量是 `delay_vs_dec5_days`。解释变量包括 10 月均温、11 月均温、10—11 月均温、11/1—12/10 均温，以及冷天数量。
#
# 这里先看最核心的相关性表：

# %%
corr_labels = {
    "oct_nov_mean_c": "10-11月均温",
    "nov_mean_c": "11月均温",
    "nov_dec10_mean_c": "11/1-12/10均温",
    "nov_dec10_days_le_10c": "11/1-12/10 ≤10°C天数",
    "dec_mean_c": "12月均温",
    "oct_mean_c": "10月均温",
}
corr_by_metric = {r["metric"]: r for r in correlations}

corr_rows = []
for metric in ["oct_nov_mean_c", "nov_mean_c", "nov_dec10_mean_c", "nov_dec10_days_le_10c", "dec_mean_c", "oct_mean_c"]:
    r = corr_by_metric[metric]
    corr_rows.append([corr_labels[metric], r["n"], f"{float(r['pearson_r']):+.3f}", f"{float(r['slope_days_per_unit']):+.2f}", f"{float(r['r2']):.3f}"])

print_table(corr_rows, ["metric", "n", "Pearson r", "slope days/unit", "R²"])
# Out:
# metric             | n  | Pearson r | slope days/unit | R²
# -------------------+----+-----------+-----------------+------
# 10-11月均温           | 15 | +0.729    | +4.37           | 0.531
# 11月均温              | 15 | +0.714    | +2.98           | 0.509
# 11/1-12/10均温       | 15 | +0.709    | +3.01           | 0.503
# 11/1-12/10 ≤10°C天数 | 15 | -0.644    | -0.65           | 0.415
# 12月均温              | 15 | +0.393    | +1.55           | 0.155
# 10月均温              | 15 | +0.309    | +1.29           | 0.095

# %% [markdown]
# ## 4. 图表辅助说明
#
# 下面三张图分别回答：
#
# 1. 哪些年份明显早/晚？
# 2. 11 月均温和红叶晚到什么程度？
# 3. 哪些气温指标最有解释力？

# %%
def show_svg(svg):
    try:
        from IPython.display import HTML, display
        display(HTML(svg))
    except Exception:
        print(svg)


def scale(value, old_min, old_max, new_min, new_max):
    if old_max == old_min:
        return (new_min + new_max) / 2
    return new_min + (value - old_min) * (new_max - new_min) / (old_max - old_min)


def regression(xs, ys):
    mean_x = sum(xs) / len(xs)
    mean_y = sum(ys) / len(ys)
    ss_x = sum((x - mean_x) ** 2 for x in xs)
    slope = sum((x - mean_x) * (y - mean_y) for x, y in zip(xs, ys)) / ss_x
    return slope, mean_y - slope * mean_x


def svg_base(parts, width, height):
    style = "<style>.axis{stroke:#334155;stroke-width:1}.grid{stroke:#e2e8f0;stroke-width:1}.label{font-family:Arial,sans-serif;font-size:12px;fill:#334155}.title{font-family:Arial,sans-serif;font-size:18px;font-weight:700;fill:#0f172a}.note{font-family:Arial,sans-serif;font-size:12px;fill:#64748b}</style>"
    return f'<svg xmlns="http://www.w3.org/2000/svg" width="{width}" height="{height}" viewBox="0 0 {width} {height}">' + style + "".join(parts) + "</svg>"


def make_delay_line_svg(rows):
    pts = [(int(r["year"]), float(r["delay_vs_dec5_days"])) for r in rows if r["delay_vs_dec5_days"]]
    xs = [p[0] for p in pts]
    ys = [p[1] for p in pts]
    width, height, ml, mr, mt, mb = 820, 380, 70, 30, 55, 60
    x0, x1 = min(xs), max(xs)
    y0, y1 = min(-5, min(ys)), max(16, max(ys))
    parts = [f'<text class="title" x="{width/2}" y="28" text-anchor="middle">官方红叶日相对 12/5 的偏移</text>']
    for y in range(int(y0), int(y1) + 1, 5):
        py = scale(y, y0, y1, height - mb, mt)
        parts.append(f'<line class="grid" x1="{ml}" y1="{py:.1f}" x2="{width-mr}" y2="{py:.1f}"/>')
        parts.append(f'<text class="label" x="{ml-10}" y="{py+4:.1f}" text-anchor="end">{y:+d}</text>')
    parts.append(f'<line class="axis" x1="{ml}" y1="{height-mb}" x2="{width-mr}" y2="{height-mb}"/>')
    parts.append(f'<line class="axis" x1="{ml}" y1="{mt}" x2="{ml}" y2="{height-mb}"/>')
    path = " ".join(f'{scale(x, x0, x1, ml, width-mr):.1f},{scale(y, y0, y1, height-mb, mt):.1f}' for x, y in pts)
    parts.append(f'<polyline fill="none" stroke="#dc2626" stroke-width="2.5" points="{path}"/>')
    for year, delay in pts:
        px = scale(year, x0, x1, ml, width - mr)
        py = scale(delay, y0, y1, height - mb, mt)
        color = "#b91c1c" if year == 2024 else "#f97316"
        parts.append(f'<circle cx="{px:.1f}" cy="{py:.1f}" r="4" fill="{color}"/>')
        if year in (2017, 2024, 2025):
            parts.append(f'<text class="label" x="{px:.1f}" y="{py-9:.1f}" text-anchor="middle">{year} {delay:+.0f}d</text>')
    for year in range(x0, x1 + 1, 3):
        px = scale(year, x0, x1, ml, width - mr)
        parts.append(f'<text class="label" x="{px:.1f}" y="{height-mb+22}" text-anchor="middle">{year}</text>')
    parts.append(f'<text class="note" x="{width/2}" y="{height-18}" text-anchor="middle">正值=比平年晚；2021 缺测未画点</text>')
    return svg_base(parts, width, height)


def make_nov_scatter_svg(rows):
    pts = [(float(r["nov_mean_c"]), float(r["delay_vs_dec5_days"]), int(r["year"])) for r in rows if r["delay_vs_dec5_days"]]
    xs = [p[0] for p in pts]
    ys = [p[1] for p in pts]
    width, height, ml, mr, mt, mb = 820, 420, 80, 40, 55, 70
    x0, x1 = min(xs) - 0.4, max(xs) + 0.4
    y0, y1 = min(-5, min(ys)), max(16, max(ys))
    slope, intercept = regression(xs, ys)
    parts = [f'<text class="title" x="{width/2}" y="28" text-anchor="middle">11月均温 vs 官方红叶延迟</text>']
    for y in range(int(y0), int(y1) + 1, 5):
        py = scale(y, y0, y1, height - mb, mt)
        parts.append(f'<line class="grid" x1="{ml}" y1="{py:.1f}" x2="{width-mr}" y2="{py:.1f}"/>')
        parts.append(f'<text class="label" x="{ml-10}" y="{py+4:.1f}" text-anchor="end">{y:+d}</text>')
    for x in [11, 12, 13, 14, 15]:
        px = scale(x, x0, x1, ml, width - mr)
        parts.append(f'<line class="grid" x1="{px:.1f}" y1="{mt}" x2="{px:.1f}" y2="{height-mb}"/>')
        parts.append(f'<text class="label" x="{px:.1f}" y="{height-mb+22}" text-anchor="middle">{x}°C</text>')
    parts.append(f'<line class="axis" x1="{ml}" y1="{height-mb}" x2="{width-mr}" y2="{height-mb}"/>')
    parts.append(f'<line class="axis" x1="{ml}" y1="{mt}" x2="{ml}" y2="{height-mb}"/>')
    trend = " ".join(f'{scale(x, x0, x1, ml, width-mr):.1f},{scale(intercept + slope*x, y0, y1, height-mb, mt):.1f}' for x in (min(xs), max(xs)))
    parts.append(f'<polyline fill="none" stroke="#2563eb" stroke-width="2.5" points="{trend}"/>')
    for x, y, year in pts:
        px = scale(x, x0, x1, ml, width - mr)
        py = scale(y, y0, y1, height - mb, mt)
        color = "#b91c1c" if year == 2024 else "#0ea5e9"
        parts.append(f'<circle cx="{px:.1f}" cy="{py:.1f}" r="5" fill="{color}" opacity="0.9"/>')
        if year in (2015, 2017, 2024, 2025):
            parts.append(f'<text class="label" x="{px+7:.1f}" y="{py-7:.1f}">{year}</text>')
    parts.append(f'<text class="note" x="{width/2}" y="{height-34}" text-anchor="middle">线性斜率约 {slope:.1f} 天/°C；Pearson r≈0.714</text>')
    parts.append(f'<text class="note" x="{width/2}" y="{height-16}" text-anchor="middle">横轴=11月均温；纵轴=相对 12/5 延迟天数</text>')
    return svg_base(parts, width, height)


def make_correlation_bar_svg(corr_by_metric):
    selected = [
        ("10-11月均温", float(corr_by_metric["oct_nov_mean_c"]["pearson_r"])),
        ("11月均温", float(corr_by_metric["nov_mean_c"]["pearson_r"])),
        ("11/1-12/10均温", float(corr_by_metric["nov_dec10_mean_c"]["pearson_r"])),
        ("≤10°C冷天数", float(corr_by_metric["nov_dec10_days_le_10c"]["pearson_r"])),
        ("12月均温", float(corr_by_metric["dec_mean_c"]["pearson_r"])),
        ("10月均温", float(corr_by_metric["oct_mean_c"]["pearson_r"])),
    ]
    width, height, ml, mr, mt, mb = 820, 390, 190, 50, 55, 40
    zero_x = scale(0, -0.8, 0.8, ml, width - mr)
    parts = [f'<text class="title" x="{width/2}" y="28" text-anchor="middle">各气温指标与红叶延迟的相关性</text>']
    parts.append(f'<line class="axis" x1="{zero_x:.1f}" y1="{mt}" x2="{zero_x:.1f}" y2="{height-mb}"/>')
    for i, (label, r) in enumerate(selected):
        y = mt + i * 48
        x = scale(min(0, r), -0.8, 0.8, ml, width - mr)
        bar_width = abs(scale(r, -0.8, 0.8, ml, width - mr) - zero_x)
        color = "#ef4444" if r > 0 else "#2563eb"
        tx = scale(r, -0.8, 0.8, ml, width - mr)
        anchor = "start" if r >= 0 else "end"
        offset = 6 if r >= 0 else -6
        parts.append(f'<text class="label" x="{ml-12}" y="{y+21}" text-anchor="end">{label}</text>')
        parts.append(f'<rect x="{x:.1f}" y="{y}" width="{bar_width:.1f}" height="32" rx="4" fill="{color}" opacity="0.85"/>')
        parts.append(f'<text class="label" x="{tx+offset:.1f}" y="{y+21}" text-anchor="{anchor}">{r:+.3f}</text>')
    parts.append(f'<text class="note" x="{width/2}" y="{height-15}" text-anchor="middle">红色=越暖越晚；蓝色=冷天越多越早</text>')
    return svg_base(parts, width, height)

# %% [markdown]
# ### 4.1 年度走势：2024 是样本内最晚年份

# %%
# 年度走势：2024 是样本内最晚年份。
show_svg(make_delay_line_svg(summary))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" width="820" height="380" viewBox="0 0 820 380"><style>.axis{stroke:#334155;stroke-width:1}.grid{stroke:#e2e8f0;stroke-width:1}.label{font-family:Arial,sans-serif;font-size:12px;fill:#334155}.title{font-family:Arial,sans-serif;font-size:18px;font-weight:700;fill:#0f172a}.note{font-family:Arial,sans-serif;font-size:12px;fill:#64748b}</style><text class="title" x="410.0" y="28" text-anchor="middle">官方红叶日相对 12/5 的偏移</text><line class="grid" x1="70" y1="320.0" x2="790" y2="320.0"/><text class="label" x="60" y="324.0" text-anchor="end">-5</text><line class="grid" x1="70" y1="256.9" x2="790" y2="256.9"/><text class="label" x="60" y="260.9" text-anchor="end">+0</text><line class="grid" x1="70" y1="193.8" x2="790" y2="193.8"/><text class="label" x="60" y="197.8" text-anchor="end">+5</text><line class="grid" x1="70" y1="130.7" x2="790" y2="130.7"/><text class="label" x="60" y="134.7" text-anchor="end">+10</text><line class="grid" x1="70" y1="67.6" x2="790" y2="67.6"/><text class="label" x="60" y="71.6" text-anchor="end">+15</text><line class="axis" x1="70" y1="320" x2="790" y2="320"/><line class="axis" x1="70" y1="55" x2="70" y2="320"/><polyline fill="none" stroke="#dc2626" stroke-width="2.5" points="70.0,156.0 118.0,143.3 166.0,231.7 214.0,256.9 262.0,206.4 310.0,143.3 358.0,244.3 406.0,307.4 454.0,168.6 502.0,193.8 550.0,231.7 646.0,168.6 694.0,156.0 742.0,67.6 790.0,193.8"/><circle cx="70.0" cy="156.0" r="4" fill="#f97316"/><circle cx="118.0" cy="143.3" r="4" fill="#f97316"/><circle cx="166.0" cy="231.7" r="4" fill="#f97316"/><circle cx="214.0" cy="256.9" r="4" fill="#f97316"/><circle cx="262.0" cy="206.4" r="4" fill="#f97316"/><circle cx="310.0" cy="143.3" r="4" fill="#f97316"/><circle cx="358.0" cy="244.3" r="4" fill="#f97316"/><circle cx="406.0" cy="307.4" r="4" fill="#f97316"/><text class="label" x="406.0" y="298.4" text-anchor="middle">2017 -4d</text><circle cx="454.0" cy="168.6" r="4" fill="#f97316"/><circle cx="502.0" cy="193.8" r="4" fill="#f97316"/><circle cx="550.0" cy="231.7" r="4" fill="#f97316"/><circle cx="646.0" cy="168.6" r="4" fill="#f97316"/><circle cx="694.0" cy="156.0" r="4" fill="#f97316"/><circle cx="742.0" cy="67.6" r="4" fill="#b91c1c"/><text class="label" x="742.0" y="58.6" text-anchor="middle">2024 +15d</text><circle cx="790.0" cy="193.8" r="4" fill="#f97316"/><text class="label" x="790.0" y="184.8" text-anchor="middle">2025 +5d</text><text class="label" x="70.0" y="342" text-anchor="middle">2010</text><text class="label" x="214.0" y="342" text-anchor="middle">2013</text><text class="label" x="358.0" y="342" text-anchor="middle">2016</text><text class="label" x="502.0" y="342" text-anchor="middle">2019</text><text class="label" x="646.0" y="342" text-anchor="middle">2022</text><text class="label" x="790.0" y="342" text-anchor="middle">2025</text><text class="note" x="410.0" y="362" text-anchor="middle">正值=比平年晚；2021 缺测未画点</text></svg>

# %% [markdown]
# ### 4.2 散点回归：11 月越暖，官方红叶越晚
#
# 这张图是旅行判断最有用的一张。10 月很热不一定直接决定红叶大幅推迟；11 月是否持续偏暖更关键。

# %%
# 散点回归：11 月均温越高，官方红叶越晚。
show_svg(make_nov_scatter_svg(summary))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" width="820" height="420" viewBox="0 0 820 420"><style>.axis{stroke:#334155;stroke-width:1}.grid{stroke:#e2e8f0;stroke-width:1}.label{font-family:Arial,sans-serif;font-size:12px;fill:#334155}.title{font-family:Arial,sans-serif;font-size:18px;font-weight:700;fill:#0f172a}.note{font-family:Arial,sans-serif;font-size:12px;fill:#64748b}</style><text class="title" x="410.0" y="28" text-anchor="middle">11月均温 vs 官方红叶延迟</text><line class="grid" x1="80" y1="350.0" x2="780" y2="350.0"/><text class="label" x="70" y="354.0" text-anchor="end">-5</text><line class="grid" x1="80" y1="279.8" x2="780" y2="279.8"/><text class="label" x="70" y="283.8" text-anchor="end">+0</text><line class="grid" x1="80" y1="209.5" x2="780" y2="209.5"/><text class="label" x="70" y="213.5" text-anchor="end">+5</text><line class="grid" x1="80" y1="139.3" x2="780" y2="139.3"/><text class="label" x="70" y="143.3" text-anchor="end">+10</text><line class="grid" x1="80" y1="69.0" x2="780" y2="69.0"/><text class="label" x="70" y="73.0" text-anchor="end">+15</text><line class="grid" x1="124.8" y1="55" x2="124.8" y2="350"/><text class="label" x="124.8" y="372" text-anchor="middle">11°C</text><line class="grid" x1="295.0" y1="55" x2="295.0" y2="350"/><text class="label" x="295.0" y="372" text-anchor="middle">12°C</text><line class="grid" x1="465.2" y1="55" x2="465.2" y2="350"/><text class="label" x="465.2" y="372" text-anchor="middle">13°C</text><line class="grid" x1="635.3" y1="55" x2="635.3" y2="350"/><text class="label" x="635.3" y="372" text-anchor="middle">14°C</text><line class="grid" x1="805.5" y1="55" x2="805.5" y2="350"/><text class="label" x="805.5" y="372" text-anchor="middle">15°C</text><line class="axis" x1="80" y1="350" x2="780" y2="350"/><line class="axis" x1="80" y1="55" x2="80" y2="350"/><polyline fill="none" stroke="#2563eb" stroke-width="2.5" points="148.1,280.9 711.9,142.3"/><circle cx="253.0" cy="167.4" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="600.2" cy="153.3" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="148.1" cy="251.7" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="211.6" cy="279.8" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="490.1" cy="223.6" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="711.9" cy="153.3" r="5" fill="#0ea5e9" opacity="0.9"/><text class="label" x="718.9" y="146.3">2015</text><circle cx="378.4" cy="265.7" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="158.3" cy="336.0" r="5" fill="#0ea5e9" opacity="0.9"/><text class="label" x="165.3" y="329.0">2017</text><circle cx="548.6" cy="181.4" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="452.1" cy="209.5" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="571.8" cy="251.7" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="656.9" cy="181.4" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="523.6" cy="167.4" r="5" fill="#0ea5e9" opacity="0.9"/><circle cx="668.8" cy="69.0" r="5" fill="#b91c1c" opacity="0.9"/><text class="label" x="675.8" y="62.0">2024</text><circle cx="375.5" cy="209.5" r="5" fill="#0ea5e9" opacity="0.9"/><text class="label" x="382.5" y="202.5">2025</text><text class="note" x="410.0" y="386" text-anchor="middle">线性斜率约 3.0 天/°C；Pearson r≈0.714</text><text class="note" x="410.0" y="404" text-anchor="middle">横轴=11月均温；纵轴=相对 12/5 延迟天数</text></svg>

# %% [markdown]
# ### 4.3 指标比较：10—11 月整体均温、11 月均温最值得盯

# %%
# 指标比较：10—11 月整体均温和 11 月均温最值得盯。
show_svg(make_correlation_bar_svg(corr_by_metric))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" width="820" height="390" viewBox="0 0 820 390"><style>.axis{stroke:#334155;stroke-width:1}.grid{stroke:#e2e8f0;stroke-width:1}.label{font-family:Arial,sans-serif;font-size:12px;fill:#334155}.title{font-family:Arial,sans-serif;font-size:18px;font-weight:700;fill:#0f172a}.note{font-family:Arial,sans-serif;font-size:12px;fill:#64748b}</style><text class="title" x="410.0" y="28" text-anchor="middle">各气温指标与红叶延迟的相关性</text><line class="axis" x1="480.0" y1="55" x2="480.0" y2="350"/><text class="label" x="178" y="76" text-anchor="end">10-11月均温</text><rect x="480.0" y="55" width="264.2" height="32" rx="4" fill="#ef4444" opacity="0.85"/><text class="label" x="750.2" y="76" text-anchor="start">+0.729</text><text class="label" x="178" y="124" text-anchor="end">11月均温</text><rect x="480.0" y="103" width="258.7" height="32" rx="4" fill="#ef4444" opacity="0.85"/><text class="label" x="744.7" y="124" text-anchor="start">+0.714</text><text class="label" x="178" y="172" text-anchor="end">11/1-12/10均温</text><rect x="480.0" y="151" width="257.1" height="32" rx="4" fill="#ef4444" opacity="0.85"/><text class="label" x="743.1" y="172" text-anchor="start">+0.709</text><text class="label" x="178" y="220" text-anchor="end">≤10°C冷天数</text><rect x="246.5" y="199" width="233.5" height="32" rx="4" fill="#2563eb" opacity="0.85"/><text class="label" x="240.5" y="220" text-anchor="end">-0.644</text><text class="label" x="178" y="268" text-anchor="end">12月均温</text><rect x="480.0" y="247" width="142.6" height="32" rx="4" fill="#ef4444" opacity="0.85"/><text class="label" x="628.6" y="268" text-anchor="start">+0.393</text><text class="label" x="178" y="316" text-anchor="end">10月均温</text><rect x="480.0" y="295" width="112.0" height="32" rx="4" fill="#ef4444" opacity="0.85"/><text class="label" x="598.0" y="316" text-anchor="start">+0.309</text><text class="note" x="410.0" y="375" text-anchor="middle">红色=越暖越晚；蓝色=冷天越多越早</text></svg>

# %% [markdown]
# ## 5. 总结结论
#
# 把统计结果翻译成攻略规则：
#
# - **正常年份：** 核心赏枫窗口放在 11月28日—12月10日。
# - **11 月显著偏暖：** 后移到 12月3日—12月14日。
# - **11 月明显偏冷：** 可以提前到 11月22日—12月5日。
# - **10 月热但 11 月转冷：** 不必过度恐慌，2025 年就是例子。
# - **10 月热、11 月也暖：** 警惕 2024 年这种大幅推迟。

# %%
print("业务结论:")
print("1. 不要只盯 10 月热不热；10 月单独相关性弱。")
print("2. 11 月均温是更可操作的信号：每 +1°C，官方红叶日约晚 3 天。")
print("3. 10—11 月整体偏暖是最强的温度指标：每 +1°C，约晚 4.4 天。")
print("4. 11/1—12/10 的 ≤10°C 冷天越多，红叶推进越快。")
print("5. 攻略默认押 11月28日—12月10日；若 11 月显著偏暖，后移到 12月3日—12月14日。")
# Out:
# 业务结论:
# 1. 不要只盯 10 月热不热；10 月单独相关性弱。
# 2. 11 月均温是更可操作的信号：每 +1°C，官方红叶日约晚 3 天。
# 3. 10—11 月整体偏暖是最强的温度指标：每 +1°C，约晚 4.4 天。
# 4. 11/1—12/10 的 ≤10°C 冷天越多，红叶推进越快。
# 5. 攻略默认押 11月28日—12月10日；若 11 月显著偏暖，后移到 12月3日—12月14日。
